# %%
# !pip install openseespy
# Out:
# Collecting openseespy
#   Downloading openseespy-3.4.0.1-py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.9/86.9 KB 3.8 MB/s eta 0:00:00
# Collecting openseespylinux>=3.4.0.1
#   Downloading openseespylinux-3.4.0.1-py3-none-any.whl (11.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.7/11.7 MB 1.8 MB/s eta 0:00:0000:0100:01
# Installing collected packages: openseespylinux, openseespy
# Successfully installed openseespy-3.4.0.1 openseespylinux-3.4.0.1

# %%
import openseespy.opensees as ops

# %%
ops.wipe()
ops.model('basic','-ndm',2,'-ndf',2)

L = 10
h = 2
t = 1

ops.node(1,0,-h/2)
ops.node(2,0,h/2)
ops.node(3,L,h/2)
ops.node(4,L,-h/2)

# %%
c = h/5

#              tag Npts nodes type dof size
ops.mesh('line',1,  2, *[1,2],  0,  2,   c)
ops.mesh('line',2,  2, *[2,3],  0,  2,   c)
ops.mesh('line',3,  2, *[3,4],  0,  2,   c)
ops.mesh('line',4,  2, *[4,1],  0,  2,   c)

# %%
E = 29000
v = 0.3

ops.nDMaterial('ElasticIsotropic',1,E,v)

#             tag Nlines   lines  type dof size <ele args>
ops.mesh('tri',5,   4,  *[1,2,3,4], 0,  2,   c, 'tri31',t,'PlaneStress',1)
# Out:
# Tri31 - Written by Roozbeh G. Mikola and N.Sitar, UC Berkeley

# %%
ops.fixX(0,1,1)
