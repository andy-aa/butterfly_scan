# %%
2+2
# Out:
# 4

# %% [markdown]
# $x^2$

# %%
"111"
# Out:
# '111'

# %%
'11'
# Out:
# '11'

# %%
2 + int('5')
# Out:
# 7

# %%
[1,'2']
# Out:
# [1, '2']

# %%
c = 'helo'

# %%
c.capitalize()
# Out:
# 'Helo'

# %%
ll = [1,2]
ll.append(2)

# %%
print(ll)
# Out:
# [1, 2, 2]

# %%
x= list(range(10))
x[1:3]
# Out:
# [1, 2]

# %%
[1,2,3,4][-1:]
# Out:
# [4]
